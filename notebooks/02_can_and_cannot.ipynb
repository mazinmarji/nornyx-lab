# %% [markdown]
# # Lab 02 — What governance can and cannot guarantee
#
# **PART I — Why governed agentic systems are needed**
# *Ch. 3 — What Governance Can and Cannot Guarantee*
#
# `beginner` · about 20 minutes
#
# ## By the end of this lab you will be able to
#
# - Distinguish the five assertion layers and what each establishes
# - Treat integrity, authenticity, and completeness as independent dimensions
# - Say exactly which dimension a signature improves and which two it does not
# - Choose fail-open or fail-closed deliberately and observe the difference
#
# **Concepts:** `assertion layers`, `integrity`, `authenticity`, `completeness`, `fail-closed`, `fail-open`, `the eight questions`
#
# ---
#
# Run the cell below. It executes the *same* `lab.py` the CLI runs — this notebook is a second view onto one implementation, not a copy, so the two can never disagree.

# %%
# Make the repository importable from anywhere under notebooks/
import sys, pathlib
ROOT = pathlib.Path.cwd()
while not (ROOT / 'pyproject.toml').exists() and ROOT != ROOT.parent:
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'src'))

from nornyx_lab.engine import find_lab, run_lab
meta = find_lab('02')
print(meta.title)

# %% [markdown]
# ## Run the lab

# %%
ctx = run_lab(find_lab('02'))

# %% [markdown]
# ## Inspect what the lab measured
#
# Every lab publishes its findings with `ctx.record(...)`. This is the same data `checks.py` asserts on — poke at it.

# %%
import json
print(json.dumps(ctx.results, indent=2, default=str))

# %% [markdown]
# ## Prove it
#
# The concept checks for this lab. Each one is a proposition written so a machine can settle it.

# %%
import subprocess, sys
checks = ROOT / 'labs' / '02_can_and_cannot' / 'checks.py'
proc = subprocess.run(
    [sys.executable, '-m', 'pytest', str(checks), '-v', '--no-header'],
    cwd=str(ROOT), capture_output=True, text=True,
    encoding='utf-8', errors='replace',
)
print(proc.stdout[-4000:])

# %% [markdown]
# ## Your turn
#
# The lab printed a **your turn** panel above. Do it here — edit the contract, re-run the cells, and watch which decision changes.
#
# ---
#
# Next: [Lab 03 — The vocabulary: PDP, PEP, and what a tier claims](./03_vocabulary.ipynb)

# %%
# scratch space
