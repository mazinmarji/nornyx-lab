# %% [markdown]
# # Lab 20 — Conformance, external enforcement, and the supply chain
#
# **PART V — Framework and runtime integration**
# *Ch. 25 — Adapter Conformance and Coverage · Ch. 26 — External Policy Engines · Ch. 27 — Tool Protocols and Package Governance*
#
# `advanced` · about 35 minutes
#
# ## By the end of this lab you will be able to
#
# - Distinguish runtime adapter conformance from static adapter conformance
# - State the four properties independent enforcement requires
# - Divide responsibility between a governance layer and an external enforcement system
# - Run a deterministic package scan and read its claim-versus-evidence mismatches
#
# **Concepts:** `runtime conformance`, `static conformance`, `independent enforcement`, `dual-evidence problem`, `projection drift`, `package scanning`, `claim vs evidence`, `protocol boundary`
#
# ---
#
# Run the cell below. It executes the *same* `lab.py` the CLI runs — this notebook is a second view onto one implementation, not a copy, so the two can never disagree.

# %%
# Make the repository importable from anywhere under notebooks/
import sys, pathlib
ROOT = pathlib.Path.cwd()
while not (ROOT / 'pyproject.toml').exists() and ROOT != ROOT.parent:
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'src'))

from nornyx_lab.engine import find_lab, run_lab
meta = find_lab('20')
print(meta.title)

# %% [markdown]
# ## Run the lab

# %%
ctx = run_lab(find_lab('20'))

# %% [markdown]
# ## Inspect what the lab measured
#
# Every lab publishes its findings with `ctx.record(...)`. This is the same data `checks.py` asserts on — poke at it.

# %%
import json
print(json.dumps(ctx.results, indent=2, default=str))

# %% [markdown]
# ## Prove it
#
# The concept checks for this lab. Each one is a proposition written so a machine can settle it.

# %%
import subprocess, sys
checks = ROOT / 'labs' / '20_conformance_and_supply_chain' / 'checks.py'
proc = subprocess.run(
    [sys.executable, '-m', 'pytest', str(checks), '-v', '--no-header'],
    cwd=str(ROOT), capture_output=True, text=True,
    encoding='utf-8', errors='replace',
)
print(proc.stdout[-4000:])

# %% [markdown]
# ## Your turn
#
# The lab printed a **your turn** panel above. Do it here — edit the contract, re-run the cells, and watch which decision changes.
#
# ---
#
# Next: [Lab 21 — The authoring workflow and the CI gate set](./21_authoring_and_ci.ipynb)

# %%
# scratch space
