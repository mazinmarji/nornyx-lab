# %% [markdown]
# # Lab 24 — Capstone: design, build, verify, and audit Northstar
#
# **PART VIII — Capstone**
# *Ch. 39 — Designing the Complete System · Ch. 40 — Implementation, Verification, and Assurance Review · Ch. 41 — Lessons and Trade-offs*
#
# `advanced` · about 60 minutes
#
# ## By the end of this lab you will be able to
#
# - Compose the Northstar threads into one system with a single governance source
# - Run a failure-injection programme and map each failure to the boundary that stops it
# - Produce a verification matrix tying every claim to its verifying mechanism
# - Account honestly for what the governance layer cost, and where it should not be deployed
#
# **Concepts:** `system composition`, `failure injection programme`, `verification matrix`, `claim register`, `cost ledger`, `overgovernance`, `the road from Tier 2 to Tier 3`
#
# ---
#
# Run the cell below. It executes the *same* `lab.py` the CLI runs — this notebook is a second view onto one implementation, not a copy, so the two can never disagree.

# %%
# Make the repository importable from anywhere under notebooks/
import sys, pathlib
ROOT = pathlib.Path.cwd()
while not (ROOT / 'pyproject.toml').exists() and ROOT != ROOT.parent:
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'src'))

from nornyx_lab.engine import find_lab, run_lab
meta = find_lab('24')
print(meta.title)

# %% [markdown]
# ## Run the lab

# %%
ctx = run_lab(find_lab('24'))

# %% [markdown]
# ## Inspect what the lab measured
#
# Every lab publishes its findings with `ctx.record(...)`. This is the same data `checks.py` asserts on — poke at it.

# %%
import json
print(json.dumps(ctx.results, indent=2, default=str))

# %% [markdown]
# ## Prove it
#
# The concept checks for this lab. Each one is a proposition written so a machine can settle it.

# %%
import subprocess, sys
checks = ROOT / 'labs' / '24_capstone' / 'checks.py'
proc = subprocess.run(
    [sys.executable, '-m', 'pytest', str(checks), '-v', '--no-header'],
    cwd=str(ROOT), capture_output=True, text=True,
    encoding='utf-8', errors='replace',
)
print(proc.stdout[-4000:])

# %% [markdown]
# ## Your turn
#
# The lab printed a **your turn** panel above. Do it here — edit the contract, re-run the cells, and watch which decision changes.
#
# ---
#
# That was the last lab.

# %%
# scratch space
