# %% [markdown]
# # Lab 19 — LangGraph: occurrence identity under retries and loops
#
# **PART V — Framework and runtime integration**
# *Ch. 24 — LangGraph Integration*
#
# `advanced` · about 30 minutes
#
# ## By the end of this lab you will be able to
#
# - Describe LangGraph's execution model at the level a governance integration depends on
# - Explain how occurrence identity is derived from public framework execution metadata
# - Predict what appears in evidence for a retry, a loop visit, and a parallel branch
# - Distinguish an unsupported surface from an unwrapped one
#
# **Concepts:** `state graph`, `node invocation`, `occurrence identity derivation`, `attempt identity`, `interrupt as incomplete attempt`, `cumulative resumed evidence`
#
# ---
#
# Run the cell below. It executes the *same* `lab.py` the CLI runs — this notebook is a second view onto one implementation, not a copy, so the two can never disagree.

# %%
# Make the repository importable from anywhere under notebooks/
import sys, pathlib
ROOT = pathlib.Path.cwd()
while not (ROOT / 'pyproject.toml').exists() and ROOT != ROOT.parent:
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'src'))

from nornyx_lab.engine import find_lab, run_lab
meta = find_lab('19')
print(meta.title)

# %% [markdown]
# ## Run the lab

# %%
ctx = run_lab(find_lab('19'))

# %% [markdown]
# ## Inspect what the lab measured
#
# Every lab publishes its findings with `ctx.record(...)`. This is the same data `checks.py` asserts on — poke at it.

# %%
import json
print(json.dumps(ctx.results, indent=2, default=str))

# %% [markdown]
# ## Prove it
#
# The concept checks for this lab. Each one is a proposition written so a machine can settle it.

# %%
import subprocess, sys
checks = ROOT / 'labs' / '19_langgraph_adapter' / 'checks.py'
proc = subprocess.run(
    [sys.executable, '-m', 'pytest', str(checks), '-v', '--no-header'],
    cwd=str(ROOT), capture_output=True, text=True,
    encoding='utf-8', errors='replace',
)
print(proc.stdout[-4000:])

# %% [markdown]
# ## Your turn
#
# The lab printed a **your turn** panel above. Do it here — edit the contract, re-run the cells, and watch which decision changes.
#
# ---
#
# Next: [Lab 20 — Conformance, external enforcement, and the supply chain](./20_conformance_and_supply_chain.ipynb)

# %%
# scratch space
