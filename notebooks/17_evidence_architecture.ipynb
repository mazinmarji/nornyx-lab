# %% [markdown]
# # Lab 17 — Occurrence identity, drift gates, and generated artifacts
#
# **PART IV — Nornyx architecture and language**
# *Ch. 20 — Evidence Architecture · Ch. 21 — Diagnostics and Generated Artifacts*
#
# `advanced` · about 30 minutes
#
# ## By the end of this lab you will be able to
#
# - Explain why a runtime-event schema must carry execution identity
# - Apply the attempt rules and classify retry, repeated work, and duplicate
# - Explain resume semantics and why cumulative evidence is the safer contract
# - Run a drift gate end to end and treat diagnostic codes as a public interface
#
# **Concepts:** `occurrence identity`, `attempt rules`, `legacy vs explicit mode`, `resume semantics`, `drift gate`, `byte-determinism`, `exit codes as interface`, `forbidden-content scanning`
#
# ---
#
# Run the cell below. It executes the *same* `lab.py` the CLI runs — this notebook is a second view onto one implementation, not a copy, so the two can never disagree.

# %%
# Make the repository importable from anywhere under notebooks/
import sys, pathlib
ROOT = pathlib.Path.cwd()
while not (ROOT / 'pyproject.toml').exists() and ROOT != ROOT.parent:
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'src'))

from nornyx_lab.engine import find_lab, run_lab
meta = find_lab('17')
print(meta.title)

# %% [markdown]
# ## Run the lab

# %%
ctx = run_lab(find_lab('17'))

# %% [markdown]
# ## Inspect what the lab measured
#
# Every lab publishes its findings with `ctx.record(...)`. This is the same data `checks.py` asserts on — poke at it.

# %%
import json
print(json.dumps(ctx.results, indent=2, default=str))

# %% [markdown]
# ## Prove it
#
# The concept checks for this lab. Each one is a proposition written so a machine can settle it.

# %%
import subprocess, sys
checks = ROOT / 'labs' / '17_evidence_architecture' / 'checks.py'
proc = subprocess.run(
    [sys.executable, '-m', 'pytest', str(checks), '-v', '--no-header'],
    cwd=str(ROOT), capture_output=True, text=True,
    encoding='utf-8', errors='replace',
)
print(proc.stdout[-4000:])

# %% [markdown]
# ## Your turn
#
# The lab printed a **your turn** panel above. Do it here — edit the contract, re-run the cells, and watch which decision changes.
#
# ---
#
# Next: [Lab 18 — The adapter boundary, and CrewAI end to end](./18_crewai_adapter.ipynb)

# %%
# scratch space
