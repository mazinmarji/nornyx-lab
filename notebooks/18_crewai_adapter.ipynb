# %% [markdown]
# # Lab 18 — The adapter boundary, and CrewAI end to end
#
# **PART V — Framework and runtime integration**
# *Ch. 22 — Designing an Adapter Boundary · Ch. 23 — CrewAI Integration*
#
# `advanced` · about 35 minutes
#
# ## By the end of this lab you will be able to
#
# - Assign each responsibility in a governed call to the adapter, the core, or the runtime
# - Build one governed tool: bind, wrap, allow, deny, and read the evidence
# - Read the machine-readable coverage inventory and say what each unsupported surface means
# - Apply the eight questions to 'CrewAI is governed' and produce its defensible replacement
#
# **Concepts:** `adapter boundary`, `surface binding`, `protected execution sequence`, `injected dependencies`, `version pinning as governance`, `exactly-once is local`
#
# ---
#
# Run the cell below. It executes the *same* `lab.py` the CLI runs — this notebook is a second view onto one implementation, not a copy, so the two can never disagree.

# %%
# Make the repository importable from anywhere under notebooks/
import sys, pathlib
ROOT = pathlib.Path.cwd()
while not (ROOT / 'pyproject.toml').exists() and ROOT != ROOT.parent:
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'src'))

from nornyx_lab.engine import find_lab, run_lab
meta = find_lab('18')
print(meta.title)

# %% [markdown]
# ## Run the lab

# %%
ctx = run_lab(find_lab('18'))

# %% [markdown]
# ## Inspect what the lab measured
#
# Every lab publishes its findings with `ctx.record(...)`. This is the same data `checks.py` asserts on — poke at it.

# %%
import json
print(json.dumps(ctx.results, indent=2, default=str))

# %% [markdown]
# ## Prove it
#
# The concept checks for this lab. Each one is a proposition written so a machine can settle it.

# %%
import subprocess, sys
checks = ROOT / 'labs' / '18_crewai_adapter' / 'checks.py'
proc = subprocess.run(
    [sys.executable, '-m', 'pytest', str(checks), '-v', '--no-header'],
    cwd=str(ROOT), capture_output=True, text=True,
    encoding='utf-8', errors='replace',
)
print(proc.stdout[-4000:])

# %% [markdown]
# ## Your turn
#
# The lab printed a **your turn** panel above. Do it here — edit the contract, re-run the cells, and watch which decision changes.
#
# ---
#
# Next: [Lab 19 — LangGraph: occurrence identity under retries and loops](./19_langgraph_adapter.ipynb)

# %%
# scratch space
