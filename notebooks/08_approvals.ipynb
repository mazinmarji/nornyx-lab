# %% [markdown]
# # Lab 08 — Approvals: eight ways to not be approved
#
# **PART II — Foundations of executable governance**
# *Ch. 9 — Approvals, Exceptions, and Human Accountability*
#
# `intermediate` · about 30 minutes
#
# ## By the end of this lab you will be able to
#
# - State the bindings a durable approval record must carry and what each prevents
# - Distinguish expiry, revocation, and invalidation
# - Explain from three arguments why a non-human identity can never approve
# - Apply maker-checker separation when the maker is a probabilistic planner
#
# **Concepts:** `approval binding`, `revision binding`, `approval expiry`, `revocation`, `invalidation`, `maker-checker separation`, `approval fatigue`, `bounded exception`
#
# ---
#
# Run the cell below. It executes the *same* `lab.py` the CLI runs — this notebook is a second view onto one implementation, not a copy, so the two can never disagree.

# %%
# Make the repository importable from anywhere under notebooks/
import sys, pathlib
ROOT = pathlib.Path.cwd()
while not (ROOT / 'pyproject.toml').exists() and ROOT != ROOT.parent:
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'src'))

from nornyx_lab.engine import find_lab, run_lab
meta = find_lab('08')
print(meta.title)

# %% [markdown]
# ## Run the lab

# %%
ctx = run_lab(find_lab('08'))

# %% [markdown]
# ## Inspect what the lab measured
#
# Every lab publishes its findings with `ctx.record(...)`. This is the same data `checks.py` asserts on — poke at it.

# %%
import json
print(json.dumps(ctx.results, indent=2, default=str))

# %% [markdown]
# ## Prove it
#
# The concept checks for this lab. Each one is a proposition written so a machine can settle it.

# %%
import subprocess, sys
checks = ROOT / 'labs' / '08_approvals' / 'checks.py'
proc = subprocess.run(
    [sys.executable, '-m', 'pytest', str(checks), '-v', '--no-header'],
    cwd=str(ROOT), capture_output=True, text=True,
    encoding='utf-8', errors='replace',
)
print(proc.stdout[-4000:])

# %% [markdown]
# ## Your turn
#
# The lab printed a **your turn** panel above. Do it here — edit the contract, re-run the cells, and watch which decision changes.
#
# ---
#
# Next: [Lab 09 — Enforcement models and fail-closed design](./09_enforcement.ipynb)

# %%
# scratch space
